# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
house=pd.read_csv('/content/drive/MyDrive/House_Price_Data.csv')

# %%
house
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
house['availability'].replace({'t', 'true','f','fale'}, inplace=True)
# Out:
# /tmp/ipykernel_770/4265943760.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   house['availability'].replace({'t', 'true','f','fale'}, inplace=True)
# /tmp/ipykernel_770/4265943760.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house['availability'].replace({'t', 'true','f','fale'}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
house['area_type']=le.fit_transform(house['area_type'])
house['availability']=le.fit_transform(house['availability'])
house['location']=le.fit_transform(house['location'])
house['total_sqft']=le.fit_transform(house['total_sqft'])
house['size']=le.fit_transform(house['size'])
house['society']=le.fit_transform(house['society'])

# %%
house.head()
# Out:
#    area_type  availability  location  size  society  total_sqft  bath  \
# 0          3            40       419    13      464          70   2.0
# 1          2            80       317    19     2439        1288   5.0
# 2          0            80      1179    16     2688         514   2.0
# 3          3            80       757    16     2186         602   3.0
# 4          3            80       716    13     2688         239   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
house.tail()
# Out:
#        area_type  availability  location  size  society  total_sqft  bath  \
# 13315          0            80      1252    22      209        1499   4.0
# 13316          3            80      1004    18     2688        1535   5.0
# 13317          0            80       972    13     1216         172   2.0
# 13318          3            32       907    18     2205        1680   4.0
# 13319          3            80       396     0     2688        1747   1.0
#
#        balcony  price
# 13315      0.0  231.0
# 13316      NaN  400.0
# 13317      1.0   60.0
# 13318      1.0  488.0
# 13319      1.0   17.0

# %%
house.describe()
# Out:
#           area_type  availability      location          size       society  \
# count  13320.000000  13320.000000  13320.000000  13320.000000  13320.000000
# mean       2.290315     71.081156    672.659009     14.812913   1906.121547
# std        1.143846     18.513172    365.024806      4.490614    865.637849
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000     80.000000    397.000000     13.000000   1247.750000
# 50%        3.000000     80.000000    654.000000     16.000000   2210.000000
# 75%        3.000000     80.000000    999.000000     16.000000   2688.000000
# max        3.000000     80.000000   1305.000000     31.000000   2688.000000
#
#          total_sqft          bath       balcony         price
# count  13320.000000  13247.000000  12711.000000  13320.000000
# mean     762.983258      2.692610      1.584376    112.565627
# std      630.502696      1.341458      0.817263    148.971674
# ...

# %%
house.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False    False       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False    False       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False    False       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False    False       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
house = house.fillna(0)

# %%
house.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319     True
# Length: 13320, dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(house['total_sqft'],house['area_type'])

# %%
plt.bar(house['total_sqft'],house['area_type'])
# Out:
# <BarContainer object of 13320 artists>

# %%
plt.scatter(house['total_sqft'],house['area_type'])

# %%
plt.hist(house['total_sqft'])
plt.xlabel('total_sqft')
plt.ylabel('Frequency')
plt.title('Distribution of Total Square Feet')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Square Feet')

# %%
sns.boxplot(x='area_type',y='total_sqft',data=house)
# Out:
# <Axes: xlabel='area_type', ylabel='total_sqft'>

# %%
sns.barplot(x='area_type',y='total_sqft', data=house)
# Out:
# <Axes: xlabel='area_type', ylabel='total_sqft'>

# %%
sns.scatterplot(x='area_type',y='total_sqft',data=house)
# Out:
# <Axes: xlabel='area_type', ylabel='total_sqft'>

# %%
sns.histplot(x='total_sqft',y='area_type',data=house)
# Out:
# <Axes: xlabel='total_sqft', ylabel='area_type'>

# %%
sns.axes_style('darkgrid')
sns.lineplot(x='total_sqft',y='area_type',data=house)
# Out:
# <Axes: xlabel='total_sqft', ylabel='area_type'>

# %%
house.shape
# Out:
# (13320, 9)

# %%
house.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
house['balcony'].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1638
# Name: count, dtype: int64

# %%
house['balcony'].unique()
# Out:
# array([1., 3., 0., 2.])

# %% [markdown]
# **train_test_split**

# %%
from sklearn.model_selection import train_test_split

# %%
house.head()
# Out:
#    area_type  availability  location  size  society  total_sqft  bath  \
# 0          3            40       419    13      464          70   2.0
# 1          2            80       317    19     2439        1288   5.0
# 2          0            80      1179    16     2688         514   2.0
# 3          3            80       757    16     2186         602   3.0
# 4          3            80       716    13     2688         239   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
y=house['price']
x=house.drop('price',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test.shape,x_train.shape,y_test.shape,y_train.shape
# Out:
# ((2664, 8), (10656, 8), (2664,), (10656,))

# %% [markdown]
# **Linear regression classifier**

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 44.49840951, 135.20377722,  46.0114473 , ..., 124.89420267,
#         59.15529478, 108.99838701])

# %%
model.predict([[3,56,87,65,4,6,78,54]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3133.81543435])

# %% [markdown]
# **mean_absolute_error classifier**

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 54.672001209098134

# %% [markdown]
# **knn classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=1)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=1)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
y_pred=knn.predict(x_test)

# %%
y_pred
# Out:
# array([42.  , 52.  , 42.  , ..., 80.  , 56.81, 77.5 ])

# %% [markdown]
# #accuracy of knn

# %%
from sklearn.metrics import accuracy_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 46.221225600600604

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.007375969022304085
